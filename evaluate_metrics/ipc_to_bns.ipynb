# %%
mapping = {
    '1': { 'bns': 'BNS 1(1)(2)', 'remark': 'Short title, commencement and application' },
    '2': { 'bns': 'BNS 1(3)', 'remark': 'Short title, commencement and application' },
    '3': { 'bns': 'BNS 1(4)', 'remark': 'Short title, commencement and application' },
    '4': { 'bns': 'BNS 1(5)', 'remark': 'Short title, commencement and application' },
    '5': { 'bns': 'BNS 1(6)', 'remark': 'Short title, commencement and application' },
    '6': { 'bns': 'BNS 3(1)', 'remark': 'General explanations' },
    '7': { 'bns': 'BNS 3(2)', 'remark': 'General explanations' },
    '8': { 'bns': 'BNS 2(10)', 'remark': 'Gender' },
    '9': { 'bns': 'BNS 2(22)', 'remark': 'Number' },
    '10': { 'bns': 'BNS 2(19), 2(35)', 'remark': 'Man, Woman' },
    '11': { 'bns': 'BNS 2(26)', 'remark': 'Person' },
    '12': { 'bns': 'BNS 2(27)', 'remark': 'Public' },
    '13': { 'bns': '-', 'remark': '-' },
    '14': { 'bns': '-', 'remark': '-' },
    '15': { 'bns': '-', 'remark': '-' },
    '16': { 'bns': '-', 'remark': '-' },
    '17': { 'bns': 'BNS 2(12)', 'remark': 'Government' },
    '18': { 'bns': '-', 'remark': '-' },
    '19': { 'bns': 'BNS 2(16)', 'remark': 'Judge' },
    '20': { 'bns': 'BNS 2(5)', 'remark': 'Court' },
    '21': { 'bns': 'BNS 2(28)', 'remark': 'Public servant' },
    '22': { 'bns': 'BNS 2(21)', 'remark': 'Moveable property' },
    '23': { 'bns': 'BNS 2(36)', 'remark': 'Wrongful gain' },
    '23': { 'bns': 'BNS 2(37)', 'remark': 'Wrongful loss' },
    '23': { 'bns': 'BNS 2(38)', 'remark': 'Gaining wrongfully/losing wrongfully' },
    '24': { 'bns': 'BNS 2(7)', 'remark': 'Dishonestly' },
    '25': { 'bns': 'BNS 2(9)', 'remark': 'Fraudulently' },
    '26': { 'bns': 'BNS 2(29)', 'remark': 'Reason to believe' },
    '27': { 'bns': 'BNS 3(3)', 'remark': 'General explanation' },
    '28': { 'bns': 'BNS 2(4)', 'remark': 'Counterfeit' },
    '29': { 'bns': 'BNS 2(8)', 'remark': 'Document' },
    '29A': { 'bns': '-', 'remark': '-' },
    '30': { 'bns': 'BNS 2(31)', 'remark': 'Valuable security' },
    '31': { 'bns': 'BNS 2(34)', 'remark': 'A will' },
    '32': { 'bns': 'BNS 2(1) 3(4)', 'remark': 'Act general explanations' },
    '33': { 'bns': 'BNS 2(1) 2(25)', 'remark': 'Act omission' },
    '34': { 'bns': 'BNS 3(5)', 'remark': 'General explanations' },
    '35': { 'bns': 'BNS 3(6)', 'remark': 'General explanations' },
    '36': { 'bns': 'BNS 3(7)', 'remark': 'General explanations' },
    '37': { 'bns': 'BNS 3(8)', 'remark': 'General explanations' },
    '38': { 'bns': 'BNS 3(9)', 'remark': 'General explanations' },
    '39': { 'bns': 'BNS 2(33)', 'remark': 'Voluntarily' },
    '40': { 'bns': 'BNS 2(24)', 'remark': 'Offence' },
    '41': { 'bns': 'BNS 2(30)', 'remark': 'Special law' },
    '42': { 'bns': 'BNS 2(18)', 'remark': 'Local law' },
    '43': { 'bns': 'BNS 2(15)', 'remark': 'Illegal legally bound to do' },
    '44': { 'bns': 'BNS 2(14)', 'remark': 'Injury' },
    '45': { 'bns': 'BNS 2(17)', 'remark': 'Life' },
    '46': { 'bns': 'BNS 2(6)', 'remark': 'Death' },
    '47': { 'bns': 'BNS 2(2)', 'remark': 'Animal' },
    '48': { 'bns': 'BNS 2(32)', 'remark': 'Vessel' },
    '49': { 'bns': 'BNS 2(20)', 'remark': 'Year month' },
    '50': { 'bns': '-', 'remark': '-' },
    '51': { 'bns': 'BNS 2(23)', 'remark': 'Oath' },
    '52': { 'bns': 'BNS 2(11)', 'remark': 'Good faith' },
    '52A': { 'bns': 'BNS 2(13)', 'remark': 'Harbour' },
    '53': { 'bns': 'BNS 4', 'remark': 'Punishments' },
    '53A': { 'bns': '-', 'remark': '-' },
    '54': { 'bns': 'BNS 5', 'remark': 'Commutation of sentence of death' },
    '55': { 'bns': 'BNS 5', 'remark': 'Commutation of sentence of death' },
    '55A': { 'bns': 'Explanation to section 5', 'remark': 'Commutation of sentence' },
    '56': { 'bns': '-', 'remark': '-' },
    '57': { 'bns': 'BNS 6', 'remark': 'Fractions of terms of punishments' },
    '58': { 'bns': '-', 'remark': '-' },
    '59': { 'bns': '-', 'remark': '-' },
    '60': { 'bns': 'BNS 7', 'remark': 'Sentence may be (in certain cases of imprisonment) wholly or partly rigorous or simple' },
    '61': { 'bns': '-', 'remark': '-' },
    '62': { 'bns': '-', 'remark': '-' },
    '63': { 'bns': 'BNS 8(1)', 'remark': 'Amount of fine liability in default of payment of fine etc.' },
    '64': { 'bns': 'BNS 8(2)', 'remark': 'Amount of fine liability in default of payment of fine etc.' },
    '65': { 'bns': 'BNS 8(3)', 'remark': 'Amount of fine liability in default of payment of fine etc.' },
    '66': { 'bns': 'BNS 8(4)', 'remark': 'Amount of fine liability in default of payment of fine etc.' },
    '67': { 'bns': 'BNS 8(5)', 'remark': 'Amount of fine liability in default of payment of fine etc.' },
    '68': { 'bns': 'BNS 8(6)(a)', 'remark': 'Amount of fine liability in default of payment of fine etc.' },
    '69': { 'bns': 'BNS 8(6)(b)', 'remark': 'Amount of fine liability in default of payment of fine etc.' },
    '70': { 'bns': 'BNS 8(7)', 'remark': 'Amount of fine liability in default of payment of fine etc.' },
    '71': { 'bns': 'BNS 9', 'remark': 'Limit of punishment of offence made up of several offenses' },
    '72': { 'bns': 'BNS 10', 'remark': 'Punishment of person guilty of one of several offenses, the judgment stating that it is doubtful of which' },
    '73': { 'bns': 'BNS 11', 'remark': 'Solitary confinement' },
    '74': { 'bns': 'BNS 12', 'remark': 'Limit of solitary confinement' },
    '75': { 'bns': 'BNS 13', 'remark': 'Enhanced punishment for certain offenses under chapter XII or XVII after previous conviction' },
    '76': { 'bns': 'BNS 14', 'remark': 'Act done by a person bound for mistake of fact believing himself bound by law' },
    '77': { 'bns': 'BNS 15', 'remark': 'Act of a judge when acting judicially' },
    '78': { 'bns': 'BNS 16', 'remark': 'Act done pursuant to the judgment or order of the court' },
    '79': { 'bns': 'BNS 17', 'remark': 'Act done by a person justified or by mistake of fact believing himself justified by law' },
    '80': { 'bns': 'BNS 18', 'remark': 'Accident in doing a lawful act' },
    '81': { 'bns': 'BNS 19', 'remark': 'Act likely to cause harm but done without criminal intent and to prevent other harm' },
    '82': { 'bns': 'BNS 20', 'remark': 'Act of a child under 7 years of age' },
    '83': { 'bns': 'BNS 21', 'remark': 'Act of a child above 7 and under 12 of immature understanding' },
    '84': { 'bns': 'BNS 22', 'remark': 'Act of a person of unsound mind' },
    '85': { 'bns': 'BNS 23', 'remark': 'Act of a person incapable of judgment by reason of intoxication caused against his will' },
    '86': { 'bns': 'BNS 24', 'remark': 'Offense requiring a particular intent or knowledge committed by one who is intoxicated' },
    '87': { 'bns': 'BNS 25', 'remark': 'Act not intended and not known to be likely to cause death or grievous hurt done by consent' },
    '88': { 'bns': 'BNS 26', 'remark': 'Act not intended to cause death done by consent in good faith for person’s benefit' },
    '89': { 'bns': 'BNS 27', 'remark': 'Act done in good faith for benefit of child or insane person by or by consent of guardian' },
    '90': { 'bns': 'BNS 28', 'remark': 'Consent known to be given under fear or misconception' },
    '91': { 'bns': 'BNS 29', 'remark': 'Exclusion of acts which are offenses independently of harm caused' },
    '92': { 'bns': 'BNS 30', 'remark': 'Act done in good faith for benefit of person without consent' },
    '93': { 'bns': 'BNS 31', 'remark': 'Communication made in good faith' },
    '94': { 'bns': 'BNS 32', 'remark': 'Act of which a person is compelled by threats' },
    '95': { 'bns': 'BNS 33', 'remark': 'Act causing slight harm' },
    '96': { 'bns': 'BNS 34', 'remark': 'Things done in private defense' },
    '97': { 'bns': 'BNS 35', 'remark': 'Right of private defense of the body and of property' },
    '98': { 'bns': 'BNS 36', 'remark': 'Right of private defense against the act of a person of unsound mind etc.' },
    '99': { 'bns': 'BNS 37', 'remark': 'Act against which there is no right to private defense' },
    '100': { 'bns': 'BNS 38', 'remark': 'When the right of private defense of the body extends to causing death' },
    '101': { 'bns': 'BNS 39', 'remark': 'When such right extends to causing any harm other than death' },
    '102': { 'bns': 'BNS 40', 'remark': 'Commencement and continuance of the right of private defense of the body' },
    '103': { 'bns': 'BNS 41', 'remark': 'When the right of private defense of property extends to causing death' },
    '104': { 'bns': 'BNS 42', 'remark': 'When such right extends to causing any harm other than death' },
    '105': { 'bns': 'BNS 43', 'remark': 'Commencement and continuance of the right of private defense of property' },
    '106': { 'bns': 'BNS 44', 'remark': 'Right of private defense against deadly assault when there is the risk of harm to innocent person' },
    '107': { 'bns': 'BNS 45', 'remark': 'Abetment of a thing' },
    '108': { 'bns': 'BNS 46', 'remark': 'Abettor' },
    '108A': { 'bns': 'BNS 47', 'remark': 'Abetment in India of offenses outside India' },
    '109': { 'bns': 'BNS 49', 'remark': 'Punishment of abetment if the act abetted is committed inconsequence and where no express provision is made for its punishment' },
    '110': { 'bns': 'BNS 50', 'remark': 'Punishment of abetment if person abetted does act with a different intent from that of abettor' },
    '111': { 'bns': 'BNS 51', 'remark': 'Liability of abettor when one act abetted and different act done' },
    '112': { 'bns': 'BNS 52', 'remark': 'Abettor when liable to cumulative punishment for act abetted and for act done' },
    '113': { 'bns': 'BNS 53', 'remark': 'Liability of abettor for an effect caused by the act abetted different from that intended by the abettor' },
    '114': { 'bns': 'BNS 54', 'remark': 'Abettor present when offense is committed' },
    '115': { 'bns': 'BNS 55', 'remark': 'Abetment of offense punishable with death or life imprisonment' },
    '116': { 'bns': 'BNS 56', 'remark': 'Abetment of offense punishable by imprisonment' },
    '117': { 'bns': 'BNS 57', 'remark': 'Abetting commission of offense by the public or more than 10 persons' },
    '118': { 'bns': 'BNS 58', 'remark': 'Concealing design to commit offense punishable with death or imprisonment for life' },
    '119': { 'bns': 'BNS 59', 'remark': 'Public servant concealing design to commit offense which it is his duty to prevent' },
    '120': { 'bns': 'BNS 60', 'remark': 'Concealing design to commit offense punishable by imprisonment' },
    '120A': { 'bns': 'BNS 61(1)', 'remark': 'Definition of criminal conspiracy' },
    '120B': { 'bns': 'BNS 61(2)', 'remark': 'Punishment of criminal conspiracy' },
    '121': { 'bns': 'BNS 147', 'remark': 'Waging or attempting to wage war or abetting waging of war against the Government of India' },
    '121A': { 'bns': 'BNS 148', 'remark': 'Conspiracy to commit offenses punishable by section 147' },
    '122': { 'bns': 'BNS 149', 'remark': 'Collecting arms etc. with intention of waging war against the Government of India' },
    '123': { 'bns': 'BNS 150', 'remark': 'Concealing with intent to facilitate design to wage war' },
    '124': { 'bns': 'BNS 151', 'remark': 'Assaulting president, governor, etc. with intent to compel or restrain the exercise of any lawful power' },
    '124A': { 'bns': '-', 'remark': '-' },
    '125': { 'bns': 'BNS 153', 'remark': 'Waging war against any Asiatic power in alliance with the Government of India' },
    '126': { 'bns': 'BNS 154', 'remark': 'Committing depredation on territories of power at peace with the Government of India' },
    '127': { 'bns': 'BNS 155', 'remark': 'Receiving property taken by war or depredation mentioned in section 125 and 126' },
    '128': { 'bns': 'BNS 156', 'remark': 'Public servant voluntarily allowing prisoner of state or war to escape' },
    '129': { 'bns': 'BNS 157', 'remark': 'Public servant negligently suffering such prisoner to escape' },
    '130': { 'bns': 'BNS 158', 'remark': 'Aiding escape or rescuing or harboring such prisoner' },
    '131': { 'bns': 'BNS 159', 'remark': 'Abetting mutiny attempting to seduce a soldier, sailor, or airman from his duty' },
    '132': { 'bns': 'BNS 160', 'remark': 'Abetment of mutiny mutiny is committed in consequence thereof' },
    '133': { 'bns': 'BNS 161', 'remark': 'Abetment of assault by soldier, sailor, or airman on his superior officer when in execution of his office' },
    '134': { 'bns': 'BNS 162', 'remark': 'Abetment of such assault if the assault is committed' },
    '135': { 'bns': 'BNS 163', 'remark': 'Abetment of desertion of soldier, sailor, or airman' },
    '136': { 'bns': 'BNS 164', 'remark': 'Harboring deserter' },
    '137': { 'bns': 'BNS 165', 'remark': 'Deserter concealed on board merchant vessel through negligence of master' },
    '138': { 'bns': 'BNS 166', 'remark': 'Abetment of act of insubordination by soldiers commercial or airman' },
    '138A': { 'bns': '-', 'remark': '-' },
    '139': { 'bns': 'BNS 167', 'remark': 'Person subject to certain acts' },
    '140': { 'bns': 'BNS 168', 'remark': 'Wearing grab or carrying token used by soldier, sailor, or airman' },
    '141': { 'bns': 'BNS 189(1)', 'remark': 'Unlawful assembly' },
    '142': { 'bns': 'BNS 189(2)', 'remark': 'Unlawful assembly' },
    '143': { 'bns': 'BNS 189(2)', 'remark': 'Unlawful assembly' },
    '144': { 'bns': 'BNS 189(4)', 'remark': 'Unlawful assembly' },
    '145': { 'bns': 'BNS 189(3)', 'remark': 'Unlawful assembly' },
    '146': { 'bns': 'BNS 191(1)', 'remark': 'Rioting' },
    '147': { 'bns': 'BNS 191(2)', 'remark': 'Rioting' },
    '148': { 'bns': 'BNS 191(3)', 'remark': 'Rioting' },
    '149': { 'bns': 'BNS 190', 'remark': 'Every member of unlawful assembly guilty of offense committed in prosecution of common objects' },
    '150': { 'bns': 'BNS 189(6)', 'remark': 'Hiring or conniving at hiring of person to join unlawful assembly' },
    '151': { 'bns': 'BNS 189(5)', 'remark': 'Knowingly joining or continuing in assembly of 5 or more persons after it has been commanded to disperse' },
    '152': { 'bns': 'BNS 195(1)', 'remark': 'Assaulting or obstructing public servant when suppressing riot etc.' },
    '153': { 'bns': 'BNS 192', 'remark': 'Wantonly giving provocation with intent to cause riot – if rioting be committed or not' },
    '153A': { 'bns': 'BNS 196', 'remark': 'Promoting enmity between different groups on grounds of religion, place of birth, residence, language, etc. and doing it prejudicial to maintenance of harmony' },
    '153AA': { 'bns': '-', 'remark': '-' },
    '153B': { 'bns': 'BNS 197', 'remark': 'Imputations assertions prejudicial to national integration' },
    '154': { 'bns': 'BNS 193(1)', 'remark': 'Liability of owner, occupier, etc. of land on which an unlawful assembly or riot takes place' },
    '155': { 'bns': 'BNS 193(2)', 'remark': 'Liability of person for whose benefit riot is committed' },
    '156': { 'bns': 'BNS 193(3)', 'remark': 'Liability of agent of owner or occupier for whose benefit riot is committed' },
    '157': { 'bns': 'BNS 189(7)', 'remark': 'Unlawful assembly' },
    '158': { 'bns': 'BNS 189(8)/(9)', 'remark': 'Unlawful assembly' },
    '159': { 'bns': 'BNS 194(1)', 'remark': 'Affray' },
    '160': { 'bns': 'BNS 194(2)', 'remark': 'Affray' },
    '161 to 165A': { 'bns': '-', 'remark': '-' },
    '166': { 'bns': 'BNS 198', 'remark': 'Public servant disobeying law with intent to cause injury to any person' },
    '166A': { 'bns': 'BNS 199', 'remark': 'Public servant disobeying direction under law' },
    '166B': { 'bns': 'BNS 200', 'remark': 'Punishment for non-treatment of victim' },
    '167': { 'bns': 'BNS 201', 'remark': 'Public servant framing an incorrect document with intent to cause injury' },
    '168': { 'bns': 'BNS 202', 'remark': 'Public servant unlawfully engaging in trade' },
    '169': { 'bns': 'BNS 203', 'remark': 'Public servant unlawfully buying or bidding for property' },
    '170': { 'bns': 'BNS 204', 'remark': 'Personating a public servant' },
    '171': { 'bns': 'BNS 205', 'remark': 'Wearing grab or carrying a token used by public servant with fraudulent intent' },
    '171A': { 'bns': 'BNS 169', 'remark': 'Candidate electoral right defined' },
    '171B': { 'bns': 'BNS 170', 'remark': 'Bribery' },
    '171C': { 'bns': 'BNS 171', 'remark': 'Under influence at elections' },
    '171D': { 'bns': 'BNS 172', 'remark': 'Personation at elections' },
    '171E': { 'bns': 'BNS 173', 'remark': 'Punishment for bribery' },
    '171F': { 'bns': 'BNS 174', 'remark': 'Punishment for undue influence or personation at an election' },
    '171G': { 'bns': 'BNS 175', 'remark': 'False statement in connection with an election' },
    '171H': { 'bns': 'BNS 176', 'remark': 'Illegal payment in connection with an election' },
    '171I': { 'bns': 'BNS 177', 'remark': 'Failure to keep elections account' },
    '172': { 'bns': 'BNS 206', 'remark': 'Absconding to avoid service of summons or the proceeding' },
    '173': { 'bns': 'BNS 207', 'remark': 'Preventing service of summons or other proceedings or preventing publication thereof' },
    '174': { 'bns': 'BNS 208', 'remark': 'Non-attendance in obedience to an order from public servant' },
    '174A': { 'bns': 'BNS 209', 'remark': 'Non-appearance in response to a proclamation under section 84 of Bharatiya Nagarik Suraksha Sanhita 2023' },
    '175': { 'bns': 'BNS 210', 'remark': 'Omission to produce document or electronic record to public servant by person legally bound to produce it' },
    '176': { 'bns': 'BNS 211', 'remark': 'Omission to give notice or information to public servant by person legally bound to give it' },
    '177': { 'bns': 'BNS 212', 'remark': 'Furnishing false information' },
    '178': { 'bns': 'BNS 213', 'remark': 'Refusing oath or affirmation when duly required by public servant to make it' },
    '179': { 'bns': 'BNS 214', 'remark': 'Refusing to answer public servant authorized to question' },
    '180': { 'bns': 'BNS 215', 'remark': 'Refusing to sign statement' },
    '181': { 'bns': 'BNS 216', 'remark': 'False statement on oath or affirmation to public servant or person authorized to administer an oath or affirmation' },
    '182': { 'bns': 'BNS 217', 'remark': 'False information with intent to cause public servant to use his lawful power to the injury of another person' },
    '183': { 'bns': 'BNS 218', 'remark': 'Resistance to the taking of property by the lawful authority of a public servant' },
    '184': { 'bns': 'BNS 219', 'remark': 'Obstructing sale of property offered for sale by authority of public servant' },
    '185': { 'bns': 'BNS 220', 'remark': 'Illegal purchase or bid for property offered for sale by authority of public servant' },
    '186': { 'bns': 'BNS 221', 'remark': 'Obstructing public servant in discharge of public functions' },
    '187': { 'bns': 'BNS 222', 'remark': 'Omission to assist public servant with bound by law to give assistance' },
    '188': { 'bns': 'BNS 223', 'remark': 'Disobedience to order duly promulgated by public servant' },
    '189': { 'bns': 'BNS 224', 'remark': 'Threat of injury to public servant' },
    '190': { 'bns': 'BNS 225', 'remark': 'Threat of injury to induce a person to refrain from applying for protection from public servant' },
    '191': { 'bns': 'BNS 227', 'remark': 'Giving false evidence' },
    '192': { 'bns': 'BNS 228', 'remark': 'Fabricating false evidence' },
    '193': { 'bns': 'BNS 229', 'remark': 'Punishment for false evidence' },
    '194': { 'bns': 'BNS 230', 'remark': 'Giving or fabricating false evidence with intent to procure conviction of capital offense' },
    '195': { 'bns': 'BNS 231', 'remark': 'Giving or fabricating false evidence with intent to procure conviction of offense punishable with imprisonment for life or imprisonment' },
    '195A': { 'bns': 'BNS 232', 'remark': 'Threatening any person to give false evidence' },
    '196': { 'bns': 'BNS 233', 'remark': 'Using evidence known to be false' },
    '197': { 'bns': 'BNS 234', 'remark': 'Issuing or signing false certificate' },
    '198': { 'bns': 'BNS 235', 'remark': 'Using as true a certificate known to be false' },
    '199': { 'bns': 'BNS 236', 'remark': 'False statement made in declaration which is by law receivable as evidence' },
    '200': { 'bns': 'BNS 237', 'remark': 'Using as true such declaration knowing it to be false' },
    '201': { 'bns': 'BNS 238', 'remark': 'Causing disappearance of evidence of offense or giving false information to screen offender' },
    '202': { 'bns': 'BNS 239', 'remark': 'Intentional omission to give information of offense by person bound to inform' },
    '203': { 'bns': 'BNS 240', 'remark': 'Giving false information respecting an offense committed' },
    '204': { 'bns': 'BNS 241', 'remark': 'Destruction of document or electronic record to prevent its production as evidence' },
    '205': { 'bns': 'BNS 242', 'remark': 'False personation for the purpose of act or proceeding in suit or prosecution' },
    '206': { 'bns': 'BNS 243', 'remark': 'Fraudulent removal or concealment of property to prevent its seizure as forfeited or in execution' },
    '207': { 'bns': 'BNS 244', 'remark': 'Fraudulent claim to property to prevent its seizure as forfeited or in execution' },
    '208': { 'bns': 'BNS 245', 'remark': 'Fraudulently suffering decree for a sum not due' },
    '209': { 'bns': 'BNS 246', 'remark': 'Dishonestly making false claim in court' },
    '210': { 'bns': 'BNS 247', 'remark': 'Fraudulently obtaining decree for a sum not due' },
    '211': { 'bns': 'BNS 248', 'remark': 'False charge of offense made with intent to injure' },
    '212': { 'bns': 'BNS 249', 'remark': 'Harboring offender' },
    '213': { 'bns': 'BNS 250', 'remark': 'Taking gift etc. to screen an offender from punishment' },
    '214': { 'bns': 'BNS 251', 'remark': 'Offering gift or restoration of property in consideration of screening offender' },
    '215': { 'bns': 'BNS 252', 'remark': 'Taking gift to help to recover stolen property etc.' },
    '216': { 'bns': 'BNS 253', 'remark': 'Harboring offender who has escaped from custody or whose apprehension has been ordered' },
    '216A': { 'bns': 'BNS 254', 'remark': 'Penalty for harboring robbers or dacoits' },
    '216B': { 'bns': '-', 'remark': '-' },
    '217': { 'bns': 'BNS 255', 'remark': 'Public servant disobeying direction of law with intent to save person from punishment or property from forfeiture' },
    '218': { 'bns': 'BNS 256', 'remark': 'Public servant framing incorrect record or writing with intent to save person from punishment or property from forfeiture' },
    '219': { 'bns': 'BNS 257', 'remark': 'Public servant in judicial proceedings corruptly making a report contrary to law' },
    '220': { 'bns': 'BNS 258', 'remark': 'Commitment for trial or confinement by person having authority knowing that he is acting contrary to law' },
    '221': { 'bns': 'BNS 259', 'remark': 'Intentional omission to apprehend on the part of public servant bound to apprehend' },
    '222': { 'bns': 'BNS 260', 'remark': 'Intentional omission to apprehend on the part of public servant bound to apprehend person under sentence or lawfully committed' },
    '223': { 'bns': 'BNS 261', 'remark': 'Escape from confinement or custody negligently suffered by public servant' },
    '224': { 'bns': 'BNS 262', 'remark': 'Resistance or obstruction by a person to his lawful apprehension' },
    '225': { 'bns': 'BNS 263', 'remark': 'Resistance or obstruction to lawful apprehension of another person' },
    '225A': { 'bns': 'BNS 264', 'remark': 'Omission or sufferance of escape on the part of public servant in case not otherwise provided for' },
    '225B': { 'bns': 'BNS 265', 'remark': 'Resistance or obstruction to lawful apprehension or escape or rescue in case not otherwise provided for' },
    '226': { 'bns': '-', 'remark': '-' },
    '227': { 'bns': 'BNS 266', 'remark': 'Violation of condition of remission of punishment' },
    '228': { 'bns': 'BNS 267', 'remark': 'Disclosure of identity of the victim of certain offenses' },
    '228A': { 'bns': 'BNS 72/73', 'remark': 'Disclosure of identity of the victim of certain offenses etc./printing or publishing any matter relating to court proceedings without permission' },
    '229': { 'bns': 'BNS 268', 'remark': 'Personation of a juror or assessor' },
    '229A': { 'bns': 'BNS 269', 'remark': 'Failure by person released on bail or bond to appear in court' },
    '230': { 'bns': 'BNS 178', 'remark': 'Counterfeiting coin, government stamps, currency notes, or bank notes' },
    '231': { 'bns': 'BNS 178', 'remark': 'Counterfeiting coin, government stamps, currency notes, or bank notes' },
    '232': { 'bns': 'BNS 178', 'remark': 'counterfeiting coin government stamps currency notes or bank notes' },
    '233': { 'bns': 'BNS 181', 'remark': 'Making or selling instrument for counterfeiting coin' },
    '234': { 'bns': 'BNS 181', 'remark': 'Making or selling instrument for counterfeiting Indian coin' },
    '235': { 'bns': 'BNS 181', 'remark': 'making or possessing instruments or materials for forgoing or counterfeiting coin government stamps currency notes or bank notes' },
    '236': { 'bns': '-', 'remark': '-' },
    '237': { 'bns': '-', 'remark': '-' },
    '238': { 'bns': '-', 'remark': '-' },
    '239': { 'bns': 'BNS 179', 'remark': 'using as genuine forged or counterfeit government stamp currency notes or bank note' },
    '240': { 'bns': 'BNS 179', 'remark': 'using as genuine forged or counterfeit government stamp currency notes or bank note' },
    '241': { 'bns': 'BNS 179', 'remark': 'using as genuine forged or counterfeit government stamp currency notes or bank note' },
    '242': { 'bns': 'BNS 180', 'remark': 'Possession of forged or counterfeit government stamp currency notes or bank note' },
    '243': { 'bns': 'BNS 180', 'remark': 'Possession of forged or counterfeit government stamp currency notes or bank note' },
    '244': { 'bns': 'BNS 187', 'remark': 'person employed in mint causing coin to be of different weight or composition from that fixed by law' },
    '245': { 'bns': 'BNS 188', 'remark': 'unlawfully taking coining instrument from mint' },
    '246': { 'bns': '178', 'remark': 'counterfeiting coin government stamps currency notes or bank notes' },
    '247': { 'bns': 'BNS 178', 'remark': 'counterfeiting coin government stamps currency notes or bank notes' },
    '248': { 'bns': 'BNS 178', 'remark': 'counterfeiting coin government stamps currency notes or bank notes' },
    '249': { 'bns': 'BNS 178', 'remark': 'counterfeiting coin government stamps currency notes or bank notes' },
    '250': { 'bns': 'BNS 179', 'remark': 'using as genuine forged or counterfeit government stamp currency notes or bank note' },
    '251': { 'bns': 'BNS 179', 'remark': 'using as genuine forged or counterfeit government stamp currency notes or bank note' },
    '252': { 'bns': 'BNS 180 ', 'remark': 'Possession of coin by a person who knew it to be altered when he became possessed thereof' },
    '253': { 'bns': 'BNS 180', 'remark': 'Possession of Indian coin by a person who knew it to be altered when he became possessed thereof' },
    '254': { 'bns': 'BNS 179', 'remark': 'using as genuine forged or counterfeit government stamp currency notes or bank note' },
    '255': { 'bns': 'BNS 178', 'remark': 'Counterfeiting government stamp' },
    '256': { 'bns': 'BNS 181', 'remark': 'Making or selling instrument for counterfeiting government stamp' },
    '257': { 'bns': 'BNS 181', 'remark': 'Possession of instrument or material for the purpose of using the same for counterfeiting government stamp' },
    '258': { 'bns': 'BNS 179', 'remark': 'Sale of counterfeit government stamp' },
    '259': { 'bns': 'BNS 180', 'remark': 'Having possession of a counterfeit government stamp' },
    '260': { 'bns': 'BNS 179', 'remark': 'Using as genuine a government stamp known to be counterfeit' },
    '261': { 'bns': 'BNS 183', 'remark': 'Effacing writing from substance bearing government stamp, or removing from it any part of the stamp, or otherwise mutilating the stamp, with intent to cause loss to government' },
    '262': { 'bns': 'BNS 184', 'remark': 'Using government stamp known to have been before used' },
    '263': { 'bns': 'BNS 185', 'remark': 'Erasure of mark denoting that stamp has been used' },
    '263A': { 'bns': 'BNS 186', 'remark': 'Prohibition of fictitious stamps' },
    '264': { 'bns': '-', 'remark': '-' },
    '265': { 'bns': '-', 'remark': '-' },
    '266': { 'bns': '-', 'remark': '-' },
    '267': { 'bns': '-', 'remark': '-' },
    '268': { 'bns': 'BNS 270', 'remark': 'Public nuisance' },
    '269': { 'bns': 'BNS 271', 'remark': 'Negligent act likely to spread infection of disease dangerous to life' },
    '270': { 'bns': 'BNS 272', 'remark': 'Malignant act likely to spread infection of disease dangerous to life' },
    '271': { 'bns': 'BNS 273', 'remark': 'Disobedience to quarantine rule' },
    '272': { 'bns': 'BNS 274', 'remark': 'Adulteration of food or drink intended for sale' },
    '273': { 'bns': 'BNS 275', 'remark': 'Sale of noxious food or drink' },
    '274': { 'bns': 'BNS 276', 'remark': 'Adulteration of drugs' },
    '275': { 'bns': 'BNS 277', 'remark': 'Sale of adulterated drugs' },
    '276': { 'bns': 'BNS 278', 'remark': 'Sale of drug as a different drug or preparation' },
    '277': { 'bns': 'BNS 279', 'remark': 'Fouling water of public spring or reservoir' },
    '278': { 'bns': 'BNS 280', 'remark': 'Making the atmosphere noxious to health' },
    '279': { 'bns': 'BNS 281', 'remark': 'Rash driving or riding on a public way' },
    '280': { 'bns': 'BNS 282', 'remark': 'Rash navigation of vessel' },
    '281': { 'bns': 'BNS 283', 'remark': 'Exhibition of false light, mark, or buoy' },
    '282': { 'bns': 'BNS 284', 'remark': 'Conveying person by water for hire in an unsafe or overloaded vessel' },
    '283': { 'bns': 'BNS 285', 'remark': 'Danger or obstruction in a public way or line of navigation' },
    '284': { 'bns': 'BNS 286', 'remark': 'Negligent conduct with respect to poisonous substance' },
    '285': { 'bns': 'BNS 287', 'remark': 'Negligent conduct with respect to fire or combustible matter' },
    '286': { 'bns': 'BNS 288', 'remark': 'Negligent conduct with respect to explosive substance' },
    '287': { 'bns': 'BNS 289', 'remark': 'Negligent conduct with respect to machinery' },
    '288': { 'bns': 'BNS 290', 'remark': 'Negligent conduct with respect to pulling down or repairing buildings' },
    '289': { 'bns': 'BNS 291', 'remark': 'Negligent conduct with respect to animal' },
    '290': { 'bns': 'BNS 292', 'remark': 'Punishment for public nuisance in cases not otherwise provided for' },
    '291': { 'bns': 'BNS 293', 'remark': 'Continuance of nuisance after injunction to discontinue' },
    '292': { 'bns': 'BNS 294', 'remark': 'Sale etc. of obscene books etc.' },
    '293': { 'bns': 'BNS 295', 'remark': 'Sale etc. of obscene objects to a young person' },
    '294': { 'bns': 'BNS 296', 'remark': 'Obscene acts and songs' },
    '294A': { 'bns': 'BNS 297', 'remark': 'Keeping a lottery office' },
    '295': { 'bns': 'BNS 298', 'remark': 'Injuring or defiling a place of worship with intent to insult the religion of any class' },
    '295A': { 'bns': 'BNS 299', 'remark': 'Deliberate and malicious acts intended to outrage religious feelings of any class by insulting its religion or religious beliefs' },
    '296': { 'bns': 'BNS 300', 'remark': 'Disturbing religious assembly' },
    '297': { 'bns': 'BNS 301', 'remark': 'Trespassing on burial places etc.' },
    '298': { 'bns': 'BNS 302', 'remark': 'Uttering words etc. with deliberate intent to wound religious feelings' },
    '299': { 'bns': 'BNS 100', 'remark': 'Culpable homicide' },
    '300': { 'bns': 'BNS 101', 'remark': 'Murder' },
    '301': { 'bns': 'BNS 102', 'remark': 'Culpable homicide by causing death of person other than person whose death was intended' },
    '302': { 'bns': 'BNS 103(1)', 'remark': 'Punishment for murder' },
    '303': { 'bns': 'BNS 104', 'remark': 'punishment for murder by life convict' },
    '304': { 'bns': 'BNS 105', 'remark': 'Punishment for culpable homicide not amounting to murder' },
    '304A': { 'bns': 'BNS 106', 'remark': 'Causing death by negligence' },
    '304B': { 'bns': 'BNS 80', 'remark': 'Dowry death' },
    '305': { 'bns': 'BNS 107', 'remark': 'Abetment of suicide of a child or insane person' },
    '306': { 'bns': 'BNS 108', 'remark': 'Abetment of suicide' },
    '307': { 'bns': 'BNS 109', 'remark': 'Attempt to murder' },
    '308': { 'bns': 'BNS 110', 'remark': 'Attempt to commit culpable homicide' },
    '309': { 'bns': '-', 'remark': '-' },
    '310': { 'bns': '-', 'remark': '-' },
    '311': { 'bns': '-', 'remark': '-' },
    '312': { 'bns': 'BNS 88', 'remark': 'Causing miscarriage' },
    '313': { 'bns': 'BNS 89', 'remark': 'Causing miscarriage without a woman’s consent' },
    '314': { 'bns': 'BNS 90', 'remark': 'Death caused by an act done with intent to cause miscarriage' },
    '315': { 'bns': 'BNS 91', 'remark': 'Act done with intent to prevent a child being born alive or to cause it to die after birth' },
    '316': { 'bns': 'BNS 92', 'remark': 'Causing death of a quick unborn child by an act amounting to culpable homicide' },
    '317': { 'bns': 'BNS 93', 'remark': 'Exposure and abandonment of a child under twelve years by a parent or person having care of it' },
    '318': { 'bns': 'BNS 94', 'remark': 'Concealment of birth by secret disposal of a dead body' },
    '319': { 'bns': 'BNS 114', 'remark': 'Hurt' },
    '320': { 'bns': 'BNS 116', 'remark': 'Grievous hurt' },
    '321': { 'bns': 'BNS 115(1)', 'remark': 'Voluntarily causing hurt' },
    '322': { 'bns': 'BNS 117(1)', 'remark': 'Voluntarily causing grievous hurt' },
    '323': { 'bns': 'BNS 115(2)', 'remark': 'punishment for voluntarily causing hurt' },
    '324': { 'bns': 'BNS 118(1)', 'remark': 'voluntarily causing hurt by dangerous weapons or means' },
    '325': { 'bns': 'BNS 117(2)', 'remark': 'Punishment for voluntarily causing grievous hurt' },
    '326': { 'bns': 'BNS 118(2)', 'remark': 'voluntarily causing grievous hurt by dangerous weapons or means' },
    '326A': { 'bns': 'BNS 124(1)', 'remark': 'voluntarily causing grievous hurt by use of acid, etc' },
    '326B': { 'bns': 'BNS 124(2)', 'remark': 'voluntarily throwing or attempting to throw acid' },
    '327': { 'bns': 'BNS 119(1)', 'remark': 'voluntarily causing hurt to extort property or to constrain to an illegal act' },
    '328': { 'bns': 'BNS 123', 'remark': 'causing hurt by means of poison, ETC. With intent to commit an offence' },
    '329': { 'bns': 'BNS 119(2)', 'remark': 'voluntarily causing grievous hurt to extort property or to constrain to an illegal act' },
    '330': { 'bns': 'BNS 120(1)', 'remark': 'voluntarily causing hurt to extort confession, or to compel restoration of property' },
    '331': { 'bns': 'BNS 120(2)', 'remark': 'voluntarily causing hurt or grievous hurt  to extort confession or to compel restoration of property ' },
    '332': { 'bns': 'BNS 121(1)', 'remark': 'voluntary causing hurt or grievous hurt to deter public servant from his duty' },
    '333': { 'bns': 'BNS 121(2)', 'remark': 'voluntary causing hurt or grievous hurt to deter public servant from his duty' },
    '334': { 'bns': 'BNS 122(1)', 'remark': 'voluntarily causing hurt or grievous on provocation' },
    '335': { 'bns': 'BNS 122(2)', 'remark': 'voluntarily causing hurt or grievous on provocation' },
    '336': { 'bns': 'BNS 125', 'remark': 'act endangering  life or personal safety of others' },
    '337': { 'bns': 'BNS 125', 'remark': 'act endangering  life or personal safety of others' },
    '338': { 'bns': 'BNS 125', 'remark': 'act endangering  life or personal safety of others' },
    '339': { 'bns': 'BNS 126(1)', 'remark': 'Wrongful restraint' },
    '340': { 'bns': 'BNS 127(1)', 'remark': 'wrongful confinement' },
    '341': { 'bns': 'BNS 126(2)', 'remark': 'wrongful restraint' },
    '342': { 'bns': 'BNS 127(2)', 'remark': 'wrongful confinement' },
    '343': { 'bns': 'BNS 127(3)', 'remark': 'wrongful confinement' },
    '344': { 'bns': 'BNS 127(4)', 'remark': 'wrongful confinement' },
    '345': { 'bns': 'BNS 127(5)', 'remark': 'wrongful confinement' },
    '346': { 'bns': 'BNS 127(6)', 'remark': 'wrongful confinement' },
    '347': { 'bns': 'BNS 127(7)', 'remark': 'wrongful confinement' },
    '348': { 'bns': 'BNS 127(8)', 'remark': 'wrongful confinement' },
    '349': { 'bns': 'BNS 128', 'remark': 'Force' },
    '350': { 'bns': 'BNS 129', 'remark': 'Criminal force' },
    '351': { 'bns': 'BNS 130', 'remark': 'Assault' },
    '352': { 'bns': 'BNS 131', 'remark': 'punishment for assault or criminal force otherwise than on grave provocation' },
    '353': { 'bns': 'BNS 132', 'remark': 'assault or criminal force to deter public servant from discharge of his duty' },
    '354': { 'bns': 'BNS 74', 'remark': 'assault or use of criminal force to women with intent to outrage her modesty' },
    '354A': { 'bns': 'BNS 75', 'remark': 'sexual harassment' },
    '354B': { 'bns': 'BNS 76', 'remark': 'assault or use of criminal force to women with intent to disrobe ' },
    '354C': { 'bns': 'BNS 77', 'remark': 'Voyeurism' },
    '354D': { 'bns': 'BNS 78', 'remark': 'Stalking' },
    '355': { 'bns': 'BNS 133', 'remark': 'assault or criminal force with intent to dishonour person otherwise than on grave provocation' },
    '356': { 'bns': 'BNS 134', 'remark': 'assault or criminal force in attempt to commit theft of property carried by a person' },
    '357': { 'bns': 'BNS 135', 'remark': 'assault or criminal force in attempt wrongfully to confine a person' },
    '358': { 'bns': 'BNS 136', 'remark': 'assault or criminal force on grave  provocation' },
    '359': { 'bns': 'BNS 137(1)', 'remark': 'Kidnapping' },
    '360': { 'bns': 'BNS 137(1)(a)', 'remark': 'kidnapping' },
    '361': { 'bns': 'BNS 137(1)(b)', 'remark': 'kidnapping' },
    '362': { 'bns': 'BNS 138', 'remark': 'Abduction' },
    '363': { 'bns': 'BNS 137(2)', 'remark': 'kidnapping' },
    '363A': { 'bns': 'BNS 139', 'remark': 'kidnapping or maiming a minor for purposes of begging' },
    '364': { 'bns': 'BNS 140(1)', 'remark': 'kidnapping or abducting in order to murder or for ransom, etc. ' },
    '364A': { 'bns': 'BNS 140(2)', 'remark': 'kidnapping or abducting in order to murder or for ransom, etc.' },
    '365': { 'bns': 'BNS 140(3)', 'remark': 'kidnapping or abducting in order to murder or for ransom, etc.' },
    '366': { 'bns': 'BNS 87', 'remark': 'Kidnapping, abducting, or inducing woman to compel her marriage' },
    '366A': { 'bns': 'BNS 96', 'remark': 'procuration of minor girl' },
    '366B': { 'bns': 'BNS 141', 'remark': 'Importation of girl from a foreign country' },
    '367': { 'bns': 'BNS 140(4)', 'remark': 'kidnapping or abducting in order to murder or for ransom, etc.' },
    '368': { 'bns': 'BNS 142', 'remark': 'Wrongfully concealing or keeping in confinement, kidnapped or abducted person' },
    '369': { 'bns': 'BNS 97', 'remark': 'kidnapping or abducting child under 10 years with intent to steal from its person' },
    '370': { 'bns': 'BNS 144', 'remark': 'Trafficking of persons' },
    '370A': { 'bns': 'BNS 145', 'remark': 'habitual dealing in slaves' },
    '371': { 'bns': 'BNS 98', 'remark': 'selling minor for purpose of prostitution, ETC.' },
    '372': { 'bns': 'BNS 99', 'remark': 'buying minor for purpose of prostitution , ETC' },
    '373': { 'bns': 'BNS 146', 'remark': 'unlawful compulsory labour' },
    '374': { 'bns': 'BNS 63', 'remark': 'rape' },
    '375': { 'bns': 'BNS 64', 'remark': 'punishment for rape' },
    '376': { 'bns': 'BNS 65(1)', 'remark': 'punishment for rape' },
    '376A': { 'bns': 'BNS 66', 'remark': 'punishment for causing death or resulting in persistent vegetative state of victim' },
    '376AB': { 'bns': 'BNS 65(2)', 'remark': 'punishment for rape in certain cases ' },
    '376B': { 'bns': 'BNS 67', 'remark': 'sexual intercourse by husband upon his wife during separation' },
    '376C': { 'bns': 'BNS 68', 'remark': 'sexual intercourse by a person in authority' },
    '376D': { 'bns': 'BNS 70(1)', 'remark': 'gang rape' },
    '376DA': { 'bns': 'BNS 70(2)', 'remark': 'gang rape' },
    '376DB': { 'bns': 'BNS 70(2)', 'remark': 'gang rape' },
    '376E': { 'bns': 'BNS 71', 'remark': 'Punishment for repeat offenders' },
    '377': { 'bns': '-', 'remark': '-' },
    '378': { 'bns': 'BNS 303(1)', 'remark': 'theft' },
    '379': { 'bns': 'BNS 303(2)', 'remark': 'theft' },
    '380': { 'bns': 'BNS 305', 'remark': 'theft in dwelling house, or means of transportation or place of worship etc.' },
    '381': { 'bns': 'BNS 306', 'remark': 'Theft by clerk or servant of property in possession of master' },
    '382': { 'bns': 'BNS 307', 'remark': 'Theft after preparation made for causing death, hurt, or restraint to the committing of the theft' },
    '383': { 'bns': 'BNS 308(1)', 'remark': 'Extortion' },
    '384': { 'bns': 'BNS 308(2)', 'remark': 'extortion' },
    '385': { 'bns': 'BNS 308(3)', 'remark': 'extortion' },
    '386': { 'bns': 'BNS 308(4)', 'remark': 'extortion' },
    '387': { 'bns': 'BNS 308(5)', 'remark': 'extortion' },
    '388': { 'bns': 'BNS 308(7)', 'remark': 'extortion' },
    '389': { 'bns': 'BNS 308(6)', 'remark': 'extortion' },
    '390': { 'bns': 'BNS 309(1)/(2)/(3)', 'remark': 'Robbery' },
    '391': { 'bns': 'BNS 310(1)', 'remark': 'Dacoity' },
    '392': { 'bns': 'BNS 309(4)', 'remark': 'robbery' },
    '393': { 'bns': 'BNS 309(5)', 'remark': 'robbery' },
    '394': { 'bns': 'BNS 309(6)', 'remark': 'robbery' },
    '395': { 'bns': 'BNS 310(2)', 'remark': 'Dacoity' },
    '396': { 'bns': 'BNS 310(3)', 'remark': 'dacoity' },
    '397': { 'bns': 'BNS 311', 'remark': 'Robbery or dacoity with attempt to cause death or grievous hurt' },
    '398': { 'bns': 'BNS 312', 'remark': 'attempt to commit robbery or dacoity when armed with deadly weapons' },
    '399': { 'bns': 'BNS 310(4)', 'remark': 'dacoity' },
    '400': { 'bns': 'BNS 310(6)', 'remark': 'dacoity' },
    '401': { 'bns': 'BNS 313', 'remark': 'punishment for belonging to gang of robbers, etc. ' },
    '402': { 'bns': 'BNS 310(5)', 'remark': 'dacoity' },
    '403': { 'bns': 'BNS 314', 'remark': 'dishonest misappropriation of property' },
    '404': { 'bns': 'BNS 315', 'remark': 'dishonest misappropriation of property possessed by diseased person at the time of his death' },
    '405': { 'bns': 'BNS 316(1)', 'remark': 'Criminal breach of trust' },
    '406': { 'bns': 'BNS 316(2)', 'remark': 'criminal breach of trust' },
    '407': { 'bns': 'BNS 316(3)', 'remark': 'criminal breach of trust' },
    '408': { 'bns': 'BNS 316(4)', 'remark': 'criminal breach of trust' },
    '409': { 'bns': 'BNS 316(5)', 'remark': 'criminal breach of trust' },
    '410': { 'bns': 'BNS 317(2)', 'remark': 'Stolen property' },
    '411': { 'bns': 'BNS 317(2)', 'remark': 'stolen property' },
    '412': { 'bns': 'BNS 317(3)', 'remark': 'stolen property' },
    '413': { 'bns': 'BNS 317(4)', 'remark': 'stolen property' },
    '414': { 'bns': 'BNS 317(5)', 'remark': 'stolen property' },
    '415': { 'bns': 'BNS 318(1)', 'remark': 'Cheating' },
    '416': { 'bns': 'BNS 319(1)', 'remark': 'cheating by personation' },
    '417': { 'bns': 'BNS 318(2)', 'remark': 'Cheating' },
    '418': { 'bns': 'BNS 318(3)', 'remark': 'Cheating' },
    '419': { 'bns': 'BNS 319(2)', 'remark': 'cheating by personation' },
    '420': { 'bns': 'BNS 318(4)', 'remark': 'Cheating' },
    '422': { 'bns': 'BNS 321', 'remark': 'dishonestly or fraudulently preventing debt being available for creditors' },
    '423': { 'bns': 'BNS 322', 'remark': 'dishonest or fraudulent execution of deed of transfer containing false statement of consideration' },
    '424': { 'bns': 'BNS 323', 'remark': 'dishonest or fraudulent removable or concealment of property' },
    '425': { 'bns': 'BNS 324(1)', 'remark': 'Mischief' },
    '426': { 'bns': 'BNS 324(2)', 'remark': 'Mischief' },
    '427': { 'bns': 'BNS 324(4)/(5)', 'remark': 'Mischief' },
    '428': { 'bns': 'BNS 325', 'remark': 'Mischief by killing or maiming animal' },
    '429': { 'bns': 'BNS 325', 'remark': 'Mischief by killing or maiming animal' },
    '430': { 'bns': 'BNS 326(a)', 'remark': 'Mischief by injury , inundation , fire or explosive substance, etc. ' },
    '431': { 'bns': 'BNS 326(b)', 'remark': 'Mischief by injury , inundation , fire or explosive substance, etc. ' },
    '432': { 'bns': 'BNS 326(c)', 'remark': 'Mischief by injury , inundation , fire or explosive substance, etc. ' },
    '433': { 'bns': 'BNS 326(d)', 'remark': 'Mischief by injury , inundation , fire or explosive substance, etc. ' },
    '434': { 'bns': 'BNS 326(e)', 'remark': 'Mischief by injury , inundation , fire or explosive substance, etc. ' },
    '435': { 'bns': 'BNS 326 (f) ', 'remark': 'Mischief by injury , inundation , fire or explosive substance, etc. ' },
    '436': { 'bns': 'BNS 326(g)', 'remark': 'Mischief by injury , inundation , fire or explosive substance, etc. ' },
    '437': { 'bns': 'BNS 327(1)', 'remark': 'mischief with intent to destroy or make unsafe decked  vessel or one of 20 tons burden' },
    '438': { 'bns': 'BNS 327(2)', 'remark': 'mischief with intent to destroy or make unsafe decked  vessel or one of 20 tons burden' },
    '439': { 'bns': 'BNS 328', 'remark': 'punishment for intentionally running vessel around or ashore with intent to commit theft, etc' },
    '440': { 'bns': 'BNS 324(6)', 'remark': 'mischief' },
    '441': { 'bns': 'BNS 329(1)', 'remark': 'Criminal and house trespass' },
    '442': { 'bns': 'BNS 329(2)', 'remark': 'Criminal and house trespass' },
    '443': { 'bns': 'BNS 330(1)', 'remark': 'House trespass and house breaking ' },
    '444': { 'bns': '-', 'remark': '-' },
    '445': { 'bns': 'BNS 330(2)', 'remark': 'House trespass and house breaking' },
    '446': { 'bns': '-', 'remark': '-' },
    '447': { 'bns': 'BNS 329(3)', 'remark': 'Criminal and house trespass' },
    '448': { 'bns': 'BNS 329(4)', 'remark': 'Criminal and house trespass' },
    '449': { 'bns': 'BNS 332(a)', 'remark': 'house trespass in order to commit offence' },
    '450': { 'bns': 'BNS 332(b)', 'remark': 'house trespass in order to commit offence' },
    '451': { 'bns': 'BNS 332(c)', 'remark': 'house trespass in order to commit offence' },
    '452': { 'bns': 'BNS 333', 'remark': 'House trespass after preparation for hurt assault or wrongful restraint' },
    '453': { 'bns': 'BNS 331(1)', 'remark': 'punishment for house trespass or house breaking' },
    '454': { 'bns': 'BNS 331(3)', 'remark': 'punishment for house trespass or house breaking' },
    '455': { 'bns': 'BNS 331(5)', 'remark': 'punishment for house trespass or house breaking' },
    '456': { 'bns': 'BNS 331(2)', 'remark': 'punishment for house trespass or house breaking' },
    '457': { 'bns': 'BNS 331(4)', 'remark': 'punishment for house trespass or house breaking' },
    '458': { 'bns': 'BNS 331(6)', 'remark': 'punishment for house trespass or house breaking' },
    '459': { 'bns': 'BNS 331(7)', 'remark': 'punishment for house trespass or house breaking' },
    '460': { 'bns': 'BNS 331(8)', 'remark': 'punishment for house trespass or house breaking' },
    '461': { 'bns': 'BNS 334(1)', 'remark': 'Dishonestly breaking open receptacle containing property' },
    '462': { 'bns': 'BNS 334(2)', 'remark': 'Punishment for same offense when committed by person entrusted with custody' },
    '463': { 'bns': 'BNS 336(1)', 'remark': 'Forgery' },
    '464': { 'bns': 'BNS 335', 'remark': '-' },
    '465': { 'bns': 'BNS 336(2)', 'remark': 'forgery' },
    '466': { 'bns': 'BNS 337', 'remark': 'forgery of record of code or of public register, etc.' },
    '467': { 'bns': 'BNS 338', 'remark': 'forgery of valuable security, will, Etc.' },
    '468': { 'bns': 'BNS 336(3)', 'remark': 'forgery' },
    '469': { 'bns': 'BNS 336(4)', 'remark': 'forgery' },
    '470': { 'bns': 'BNS 340(1)', 'remark': 'forged document or electronic record using as genuine ' },
    '471': { 'bns': 'BNS 340(2)', 'remark': 'forged document or electronic record using as genuine ' },
    '472': { 'bns': 'BNS 341(1)', 'remark': 'making or possessing counterfeit seal, etc. With intent to commit forgery punishable under section 338' },
    '473': { 'bns': 'BNS 341(2)', 'remark': 'making or possessing counterfeit seal, etc. With intent to commit forgery punishable under section 338' },
    '474': { 'bns': 'BNS 339', 'remark': 'having possession of document described in section 337or 338 knowing it to be forged and intending to use it as genuine' },
    '475': { 'bns': 'BNS 342(1)', 'remark': 'counterfeiting device or mark use for authenticating documents described in section 338 or possessing counterfeit marked  material' },
    '476': { 'bns': 'BNS 342(2)', 'remark': 'counterfeiting device or mark use for authenticating documents described in section 338 or possessing counterfeit marked  material' },
    '477': { 'bns': 'BNS 343', 'remark': 'Fraudulent cancellation, destruction, etc. of will, authority to adopt or valuable security' },
    '477A': { 'bns': 'BNS 344', 'remark': 'Falsification of accounts' },
    '478': { 'bns': '-', 'remark': '-' },
    '479': { 'bns': 'BNS 345(1)', 'remark': 'property marks' },
    '480': { 'bns': '-', 'remark': '-' },
    '481': { 'bns': 'BNS 345(2)', 'remark': 'property marks' },
    '482': { 'bns': 'BNS 345(3)', 'remark': 'property marks' },
    '483': { 'bns': 'BNS 347(1)', 'remark': 'counterfeiting a property mark' },
    '484': { 'bns': 'BNS 347(2)', 'remark': 'counterfeiting a property mark' },
    '485': { 'bns': 'BNS 348', 'remark': 'Making or possession of any instrument for counterfeiting a property mark' },
    '486': { 'bns': 'BNS 349', 'remark': 'Selling goods marked with a counterfeit property mark' },
    '487': { 'bns': 'BNS 350(1)', 'remark': 'Making a false mark upon any receptacle containing goods' },
    '488': { 'bns': 'BNS 350(2)', 'remark': 'making a false mark upon any receptacle containing goods' },
    '489': { 'bns': 'BNS 346', 'remark': 'Tampering with property mark with intent to cause injury' },
    '489A': { 'bns': 'BNS 178', 'remark': 'Counterfeiting currency notes or bank notes' },
    '489B': { 'bns': 'BNS 179', 'remark': 'Using as genuine, forged or counterfeit currency notes or bank notes' },
    '489C': { 'bns': 'BNS 180', 'remark': 'possession of forged or counterfeit currency notes or bank notes' },
    '489D': { 'bns': 'BNS 181', 'remark': 'Making or possessing instruments or materials for forging or counterfeiting currency notes or bank notes' },
    '489E': { 'bns': 'BNS 182', 'remark': 'Making or using documents resembling currency or bank notes' },
    '490': { 'bns': '-', 'remark': '-' },
    '491': { 'bns': 'BNS 357', 'remark': 'breach of contract to attend on and supply wants to helpless person' },
    '492': { 'bns': '-', 'remark': '-' },
    '493': { 'bns': 'BNS 81', 'remark': 'breach of contract to attend on and supply wants to helpless person' },
    '494': { 'bns': 'BNS 82(1)', 'remark': 'Marrying again during the lifetime of a husband or wife' },
    '495': { 'bns': 'BNS 82(2)', 'remark': 'marrying again during lifetime of husband or wife' },
    '496': { 'bns': 'BNS 83', 'remark': 'Marriage ceremony fraudulently gone through without lawful marriage' },
    '497': { 'bns': '-', 'remark': '-' },
    '498': { 'bns': 'BNS 84', 'remark': 'Enticing or taking away or detaining with a criminal intent a married woman' },
    '498A': { 'bns': 'BNS 85', 'remark': 'Husband or relative of husband of a woman subjecting her to cruelty' },
    '498': { 'bns': 'BNS 86', 'remark': 'Cruelty defined' },
    '499': { 'bns': 'BNS 356(1)', 'remark': 'Defamation' },
    '500': { 'bns': 'BNS 356(2)', 'remark': 'defamation' },
    '501': { 'bns': 'BNS 356(3)', 'remark': 'defamation' },
    '502': { 'bns': 'BNS 356(4)', 'remark': 'defamation' },
    '503': { 'bns': 'BNS 351(1)', 'remark': 'Criminal intimidation' },
    '504': { 'bns': 'BNS 352', 'remark': 'Intentional insult with intent to provoke breach of the peace' },
    '505': { 'bns': 'BNS 353', 'remark': 'Statements conducing to public mischief' },
    '506': { 'bns': 'BNS 351(2)/(3)', 'remark': 'criminal intimidation' },
    '507': { 'bns': 'BNS 351(4)', 'remark': 'criminal intimidation' },
    '508': { 'bns': 'BNS 354', 'remark': 'Act caused by inducing a person to believe that he will be rendered an object of divine displeasure' },
    '509': { 'bns': 'BNS 79', 'remark': 'Word gesture or act intended to insult the modesty of a woman' },
    '510': { 'bns': 'BNS 355', 'remark': 'Misconduct in public by a drunken person' },
    '511': { 'bns': 'BNS 62', 'remark': 'Punishment for attempting to commit offenses punishable with imprisonment for life or other imprisonment' }
};

# %%
print(mapping.get('1'))
# Out:
# {'bns': 'BNS 1(1)(2)', 'remark': 'Short title, commencement and application'}

# %%
import csv
import re

with open('ipc_bns_mapping.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['IPC', 'BNS'])  # CSV header
    for ipc, data in mapping.items():
        if 'bns' in data and ' ' in data['bns']:
            after_space = data['bns'].split(' ', 1)[1]
            match = re.match(r'\d+', after_space)
            if match:
                bns_number = match.group()
                writer.writerow([ipc, bns_number])
